# %% [markdown]
# ### 人脸常见情绪：
#
# 上世纪70年代，心理学家 Paul Eckman 确定了6种基本情绪。
#
# 他认为这些情绪在所有人类文化中普遍存在，其中包括：幸福、悲伤、厌恶、恐惧、惊讶、和愤怒。
#
# 后来他又扩充了基本情绪的清单，包括骄傲、羞耻、尴尬、和兴奋等。
#
# https://zhuanlan.zhihu.com/p/574732604

# %%
## import the thrid party library!

# %%
import os
import glob
import cv2 
import math
import shutil
import config 
import numpy as np
from numpy import linalg as LA
import pandas as pd
import matplotlib.pyplot as plt
from keras.utils import to_categorical
import dlib
import tensorflow as tf
from scipy.linalg import svd
from sklearn.model_selection import train_test_split

# %%
## explain
# %!m(MISSING)atplotlib inline is a magic command in Jupyter Notebook and JupyterLab that allows you to display matplotlib plots directly in the output cell of the notebook.

# When this command is executed, it sets the backend of matplotlib to the inline backend, which renders the plots as static images embedded in the notebook. This is useful for creating data visualizations in the same notebook as your data analysis code.

# Note that this command must be executed before any plotting commands in your notebook. If you want to change the backend or customize the behavior of matplotlib, you can use other magic commands or call the relevant functions directly

# %matplotlib inline

# %%
path = glob.glob("E:/face_dectection/emotion/happy/*.jpg")
path_r="E:/face_dectection/emotion/happy"
face_write_path = 'E:\\face_dectection\\Detected\\'

# %%
filenames=[]
for f in os.listdir(path_r):
    if"jpg" in f:
        print(f)
        filenames.append(f)
# Out:
# recgonize_happy1.jpg
# recgonize_happy10.jpg
# recgonize_happy100.jpg
# recgonize_happy101.jpg
# recgonize_happy102.jpg
# recgonize_happy103.jpg
# recgonize_happy104.jpg
# recgonize_happy105.jpg
# recgonize_happy106.jpg
# recgonize_happy107.jpg
# recgonize_happy108.jpg
# recgonize_happy109.jpg
# recgonize_happy11.jpg
# recgonize_happy110.jpg
# recgonize_happy111.jpg
# recgonize_happy112.jpg
# recgonize_happy113.jpg
# recgonize_happy114.jpg
# recgonize_happy115.jpg
# recgonize_happy116.jpg
# recgonize_happy117.jpg
# recgonize_happy118.jpg
# recgonize_happy119.jpg
# recgonize_happy12.jpg
# recgonize_happy120.jpg
# recgonize_happy121.jpg
# recgonize_happy122.jpg
# recgonize_happy123.jpg
# recgonize_happy124.jpg
# recgonize_happy125.jpg
# recgonize_happy126.jpg
# recgonize_happy127.jpg
# recgonize_happy128.jpg
# recgonize_happy129.jpg
# recgonize_happy13.jpg
# recgonize_happy130.jpg
# recgonize_happy131.jpg
# recgonize_happy132.jpg
# recgonize_happy133.jpg
# recgonize_happy134.jpg
# recgonize_happy135.jpg
# recgonize_happy136.jpg
# recgonize_happy137.jpg
# recgonize_happy138.jpg
# recgonize_happy139.jpg
# recgonize_happy14.jpg
# recgonize_happy140.jpg
# recgonize_happy141.jpg
# recgonize_happy142.jpg
# recgonize_happy143.jpg
# recgonize_happy144.jpg
# recgonize_happy145.jpg
# recgonize_happy146.jpg
# recgonize_happy147.jpg
# recgonize_happy148.jpg
# recgonize_happy149.jpg
# recgonize_happy15.jpg
# recgonize_happy150.jpg
# recgonize_happy151.jpg
# recgonize_happy152.jpg
# recgonize_happy153.jpg
# recgonize_happy154.jpg
# recgonize_happy155.jpg
# recgonize_happy156.jpg
# recgonize_happy157.jpg
# recgonize_happy158.jpg
# recgonize_happy159.jpg
# recgonize_happy16.jpg
# recgonize_happy160.jpg
# recgonize_happy161.jpg
# recgonize_happy162.jpg
# recgonize_happy163.jpg
# recgonize_happy164.jpg
# recgonize_happy165.jpg
# recgonize_happy166.jpg
# recgonize_happy167.jpg
# recgonize_happy168.jpg
# recgonize_happy169.jpg
# recgonize_happy17.jpg
# recgonize_happy170.jpg
# recgonize_happy171.jpg
# recgonize_happy172.jpg
# recgonize_happy173.jpg
# recgonize_happy174.jpg
# recgonize_happy175.jpg
# recgonize_happy176.jpg
# recgonize_happy177.jpg
# recgonize_happy178.jpg
# recgonize_happy179.jpg
# recgonize_happy18.jpg
# recgonize_happy180.jpg
# recgonize_happy181.jpg
# recgonize_happy182.jpg
# recgonize_happy183.jpg
# recgonize_happy184.jpg
# recgonize_happy185.jpg
# recgonize_happy186.jpg
# recgonize_happy187.jpg
# recgonize_happy188.jpg
# recgonize_happy189.jpg
# recgonize_happy19.jpg
# recgonize_happy190.jpg
# recgonize_happy191.jpg
# recgonize_happy192.jpg
# recgonize_happy193.jpg
# recgonize_happy194.jpg
# recgonize_happy195.jpg
# recgonize_happy196.jpg
# recgonize_happy197.jpg
# recgonize_happy198.jpg
# recgonize_happy199.jpg
# recgonize_happy2.jpg
# recgonize_happy20.jpg
# recgonize_happy200.jpg
# recgonize_happy201.jpg
# recgonize_happy202.jpg
# recgonize_happy203.jpg
# recgonize_happy204.jpg
# recgonize_happy205.jpg
# recgonize_happy206.jpg
# recgonize_happy207.jpg
# recgonize_happy208.jpg
# recgonize_happy209.jpg
# recgonize_happy21.jpg
# recgonize_happy210.jpg
# recgonize_happy211.jpg
# recgonize_happy212.jpg
# recgonize_happy213.jpg
# recgonize_happy214.jpg
# recgonize_happy215.jpg
# recgonize_happy216.jpg
# recgonize_happy217.jpg
# recgonize_happy218.jpg
# recgonize_happy219.jpg
# recgonize_happy22.jpg
# recgonize_happy220.jpg
# recgonize_happy221.jpg
# recgonize_happy222.jpg
# recgonize_happy223.jpg
# recgonize_happy224.jpg
# recgonize_happy225.jpg
# recgonize_happy226.jpg
# recgonize_happy227.jpg
# recgonize_happy228.jpg
# recgonize_happy229.jpg
# recgonize_happy23.jpg
# recgonize_happy230.jpg
# recgonize_happy231.jpg
# recgonize_happy232.jpg
# recgonize_happy233.jpg
# recgonize_happy234.jpg
# recgonize_happy235.jpg
# recgonize_happy236.jpg
# recgonize_happy237.jpg
# recgonize_happy238.jpg
# recgonize_happy239.jpg
# recgonize_happy24.jpg
# recgonize_happy240.jpg
# recgonize_happy241.jpg
# recgonize_happy242.jpg
# recgonize_happy243.jpg
# recgonize_happy244.jpg
# recgonize_happy245.jpg
# recgonize_happy246.jpg
# recgonize_happy247.jpg
# recgonize_happy248.jpg
# recgonize_happy249.jpg
# recgonize_happy25.jpg
# recgonize_happy250.jpg
# recgonize_happy251.jpg
# recgonize_happy252.jpg
# recgonize_happy253.jpg
# recgonize_happy254.jpg
# recgonize_happy255.jpg
# recgonize_happy256.jpg
# recgonize_happy257.jpg
# recgonize_happy258.jpg
# recgonize_happy259.jpg
# recgonize_happy26.jpg
# recgonize_happy260.jpg
# recgonize_happy261.jpg
# recgonize_happy262.jpg
# recgonize_happy263.jpg
# recgonize_happy264.jpg
# recgonize_happy265.jpg
# recgonize_happy266.jpg
# recgonize_happy267.jpg
# recgonize_happy268.jpg
# recgonize_happy269.jpg
# recgonize_happy27.jpg
# recgonize_happy270.jpg
# recgonize_happy271.jpg
# recgonize_happy272.jpg
# recgonize_happy273.jpg
# recgonize_happy274.jpg
# recgonize_happy275.jpg
# recgonize_happy276.jpg
# recgonize_happy277.jpg
# recgonize_happy278.jpg
# recgonize_happy279.jpg
# recgonize_happy28.jpg
# recgonize_happy280.jpg
# recgonize_happy281.jpg
# recgonize_happy282.jpg
# recgonize_happy283.jpg
# recgonize_happy284.jpg
# recgonize_happy285.jpg
# recgonize_happy286.jpg
# recgonize_happy287.jpg
# recgonize_happy288.jpg
# recgonize_happy289.jpg
# recgonize_happy29.jpg
# recgonize_happy290.jpg
# recgonize_happy291.jpg
# recgonize_happy292.jpg
# recgonize_happy293.jpg
# recgonize_happy294.jpg
# recgonize_happy295.jpg
# recgonize_happy296.jpg
# recgonize_happy297.jpg
# recgonize_happy298.jpg
# recgonize_happy299.jpg
# recgonize_happy3.jpg
# recgonize_happy30.jpg
# recgonize_happy300.jpg
# recgonize_happy301.jpg
# recgonize_happy302.jpg
# recgonize_happy303.jpg
# recgonize_happy304.jpg
# recgonize_happy305.jpg
# recgonize_happy306.jpg
# recgonize_happy307.jpg
# recgonize_happy308.jpg
# recgonize_happy309.jpg
# recgonize_happy31.jpg
# recgonize_happy310.jpg
# recgonize_happy311.jpg
# recgonize_happy312.jpg
# recgonize_happy313.jpg
# recgonize_happy314.jpg
# recgonize_happy315.jpg
# recgonize_happy316.jpg
# recgonize_happy317.jpg
# recgonize_happy318.jpg
# recgonize_happy319.jpg
# recgonize_happy32.jpg
# recgonize_happy320.jpg
# recgonize_happy321.jpg
# recgonize_happy322.jpg
# recgonize_happy323.jpg
# recgonize_happy324.jpg
# recgonize_happy325.jpg
# recgonize_happy326.jpg
# recgonize_happy327.jpg
# recgonize_happy328.jpg
# recgonize_happy329.jpg
# recgonize_happy33.jpg
# recgonize_happy330.jpg
# recgonize_happy331.jpg
# recgonize_happy332.jpg
# recgonize_happy333.jpg
# recgonize_happy334.jpg
# recgonize_happy335.jpg
# recgonize_happy336.jpg
# recgonize_happy337.jpg
# recgonize_happy338.jpg
# recgonize_happy339.jpg
# recgonize_happy34.jpg
# recgonize_happy340.jpg
# recgonize_happy341.jpg
# recgonize_happy342.jpg
# recgonize_happy343.jpg
# recgonize_happy344.jpg
# recgonize_happy345.jpg
# recgonize_happy346.jpg
# recgonize_happy347.jpg
# recgonize_happy348.jpg
# recgonize_happy349.jpg
# recgonize_happy35.jpg
# recgonize_happy350.jpg
# recgonize_happy351.jpg
# recgonize_happy352.jpg
# recgonize_happy353.jpg
# recgonize_happy354.jpg
# recgonize_happy355.jpg
# recgonize_happy356.jpg
# recgonize_happy357.jpg
# recgonize_happy358.jpg
# recgonize_happy359.jpg
# recgonize_happy36.jpg
# recgonize_happy360.jpg
# recgonize_happy361.jpg
# recgonize_happy362.jpg
# recgonize_happy363.jpg
# recgonize_happy364.jpg
# recgonize_happy365.jpg
# recgonize_happy366.jpg
# recgonize_happy367.jpg
# recgonize_happy368.jpg
# recgonize_happy369.jpg
# recgonize_happy37.jpg
# recgonize_happy370.jpg
# recgonize_happy371.jpg
# recgonize_happy372.jpg
# recgonize_happy373.jpg
# recgonize_happy374.jpg
# recgonize_happy375.jpg
# recgonize_happy376.jpg
# recgonize_happy377.jpg
# recgonize_happy378.jpg
# recgonize_happy379.jpg
# recgonize_happy38.jpg
# recgonize_happy380.jpg
# recgonize_happy381.jpg
# recgonize_happy382.jpg
# recgonize_happy383.jpg
# recgonize_happy384.jpg
# recgonize_happy385.jpg
# recgonize_happy386.jpg
# recgonize_happy387.jpg
# recgonize_happy388.jpg
# recgonize_happy389.jpg
# recgonize_happy39.jpg
# recgonize_happy390.jpg
# recgonize_happy391.jpg
# recgonize_happy392.jpg
# recgonize_happy393.jpg
# recgonize_happy394.jpg
# recgonize_happy395.jpg
# recgonize_happy396.jpg
# recgonize_happy397.jpg
# recgonize_happy398.jpg
# recgonize_happy399.jpg
# recgonize_happy4.jpg
# recgonize_happy40.jpg
# recgonize_happy400.jpg
# recgonize_happy401.jpg
# recgonize_happy402.jpg
# recgonize_happy403.jpg
# recgonize_happy404.jpg
# recgonize_happy405.jpg
# recgonize_happy406.jpg
# recgonize_happy407.jpg
# recgonize_happy408.jpg
# recgonize_happy409.jpg
# recgonize_happy41.jpg
# recgonize_happy410.jpg
# recgonize_happy411.jpg
# recgonize_happy412.jpg
# recgonize_happy413.jpg
# recgonize_happy414.jpg
# recgonize_happy415.jpg
# recgonize_happy42.jpg
# recgonize_happy43.jpg
# recgonize_happy44.jpg
# recgonize_happy45.jpg
# recgonize_happy46.jpg
# recgonize_happy47.jpg
# recgonize_happy48.jpg
# recgonize_happy49.jpg
# recgonize_happy5.jpg
# recgonize_happy50.jpg
# recgonize_happy51.jpg
# recgonize_happy52.jpg
# recgonize_happy53.jpg
# recgonize_happy54.jpg
# recgonize_happy55.jpg
# recgonize_happy56.jpg
# recgonize_happy57.jpg
# recgonize_happy58.jpg
# recgonize_happy59.jpg
# recgonize_happy6.jpg
# recgonize_happy60.jpg
# recgonize_happy61.jpg
# recgonize_happy62.jpg
# recgonize_happy63.jpg
# recgonize_happy64.jpg
# recgonize_happy65.jpg
# recgonize_happy66.jpg
# recgonize_happy67.jpg
# recgonize_happy68.jpg
# recgonize_happy69.jpg
# recgonize_happy7.jpg
# recgonize_happy70.jpg
# recgonize_happy71.jpg
# recgonize_happy72.jpg
# recgonize_happy73.jpg
# recgonize_happy74.jpg
# recgonize_happy75.jpg
# recgonize_happy76.jpg
# recgonize_happy77.jpg
# recgonize_happy78.jpg
# recgonize_happy79.jpg
# recgonize_happy8.jpg
# recgonize_happy80.jpg
# recgonize_happy81.jpg
# recgonize_happy82.jpg
# recgonize_happy83.jpg
# recgonize_happy84.jpg
# recgonize_happy85.jpg
# recgonize_happy86.jpg
# recgonize_happy87.jpg
# recgonize_happy88.jpg
# recgonize_happy89.jpg
# recgonize_happy9.jpg
# recgonize_happy90.jpg
# recgonize_happy91.jpg
# recgonize_happy92.jpg
# recgonize_happy93.jpg
# recgonize_happy94.jpg
# recgonize_happy95.jpg
# recgonize_happy96.jpg
# recgonize_happy97.jpg
# recgonize_happy98.jpg
# recgonize_happy99.jpg

# %%
#picture numbers 
len(filenames)
# Out:
# 415

# %% [markdown]
# **dlib简介**
#
# Dlib是一个用C ++编写的工具库，其中包含一些机器学习方面的算法和软件，用来解决复杂现实世界问题，
# 目前该软件库在工业上和学术界都得到了广泛的使用（该库为开源库）<br>
# dlib和opencv都有可以进行人脸检测的模块。
# OpenCV的Haar Cascade运行速度快，但是容易出现将非人脸部分检测为人脸的情况，
# DNN人脸检测在各方面的表现都比较优秀，但是似乎不能使用NVIDIA GPU。
# dlib中实现了SURF、HOG和FHOG的特征提取算法。更够准确检测大部分人脸，对存在遮挡的人脸也能进行正确检测.
# 官网文档地址：http://dlib.net/

# %% [markdown]
# 参考
# https://blog.csdn.net/weixin_45909259/article/details/119746145
# https://blog.csdn.net/qq_43279579/article/details/117637044

# %%
help(dlib.get_frontal_face_detector)

# %% [markdown]
# ### 进行人脸区域的检测

# %%
#setting 
temp_image=[]
width =48
height =48
cnt=0

#use dlib dectect the image with variuos emotion
hogFaceDetector = dlib.get_frontal_face_detector()
for img in path:
    im = cv2.imread(img)
    #这个函数需要格外了解一下
    try:
        faceRects = hogFaceDetector(im, 0)
    except:
        print(img+"is not done!")
        continue
    for faceRect in faceRects:
        x = faceRect.left()
        y = faceRect.top()
        x2 = faceRect.right()
        y2 = faceRect.bottom()
    #get the region that decteced!
    try:
        c_img = im[y:y2,x:x2]
        gray = cv2.cvtColor(c_img,cv2.COLOR_BGR2GRAY)
        gray = cv2.resize(gray,(height,width))
        temp_image.append(gray)
    except:
        continue
    filename=filenames[cnt]
    #write the region that decteced to the destion path
    cv2.imwrite(os.path.join(face_write_path ,filename),gray)
    cnt=cnt+1
    print(os.path.join(face_write_path ,filename))
print("all dected image is done! plese check in your save path")
# Out:
# E:\face_dectection\Detected\recgonize_happy1.jpg
# E:\face_dectection\Detected\recgonize_happy10.jpg
# E:\face_dectection\Detected\recgonize_happy100.jpg
# E:\face_dectection\Detected\recgonize_happy101.jpg
# E:\face_dectection\Detected\recgonize_happy102.jpg
# E:\face_dectection\Detected\recgonize_happy103.jpg
# E:/face_dectection/emotion/happy\recgonize_happy105.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy104.jpg
# E:\face_dectection\Detected\recgonize_happy105.jpg
# E:\face_dectection\Detected\recgonize_happy106.jpg
# E:/face_dectection/emotion/happy\recgonize_happy109.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy107.jpg
# E:\face_dectection\Detected\recgonize_happy108.jpg
# E:\face_dectection\Detected\recgonize_happy109.jpg
# E:\face_dectection\Detected\recgonize_happy11.jpg
# E:\face_dectection\Detected\recgonize_happy110.jpg
# E:\face_dectection\Detected\recgonize_happy111.jpg
# E:\face_dectection\Detected\recgonize_happy112.jpg
# E:\face_dectection\Detected\recgonize_happy113.jpg
# E:\face_dectection\Detected\recgonize_happy114.jpg
# E:\face_dectection\Detected\recgonize_happy115.jpg
# E:\face_dectection\Detected\recgonize_happy116.jpg
# E:\face_dectection\Detected\recgonize_happy117.jpg
# E:\face_dectection\Detected\recgonize_happy118.jpg
# E:\face_dectection\Detected\recgonize_happy119.jpg
# E:/face_dectection/emotion/happy\recgonize_happy125.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy12.jpg
# E:\face_dectection\Detected\recgonize_happy120.jpg
# E:\face_dectection\Detected\recgonize_happy121.jpg
# E:\face_dectection\Detected\recgonize_happy122.jpg
# E:\face_dectection\Detected\recgonize_happy123.jpg
# E:\face_dectection\Detected\recgonize_happy124.jpg
# E:\face_dectection\Detected\recgonize_happy125.jpg
# E:\face_dectection\Detected\recgonize_happy126.jpg
# E:\face_dectection\Detected\recgonize_happy127.jpg
# E:\face_dectection\Detected\recgonize_happy128.jpg
# E:\face_dectection\Detected\recgonize_happy129.jpg
# E:\face_dectection\Detected\recgonize_happy13.jpg
# E:\face_dectection\Detected\recgonize_happy130.jpg
# E:\face_dectection\Detected\recgonize_happy131.jpg
# E:/face_dectection/emotion/happy\recgonize_happy139.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy132.jpg
# E:\face_dectection\Detected\recgonize_happy133.jpg
# E:\face_dectection\Detected\recgonize_happy134.jpg
# E:\face_dectection\Detected\recgonize_happy135.jpg
# E:\face_dectection\Detected\recgonize_happy136.jpg
# E:\face_dectection\Detected\recgonize_happy137.jpg
# E:/face_dectection/emotion/happy\recgonize_happy145.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy138.jpg
# E:\face_dectection\Detected\recgonize_happy139.jpg
# E:\face_dectection\Detected\recgonize_happy14.jpg
# E:/face_dectection/emotion/happy\recgonize_happy149.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy140.jpg
# E:\face_dectection\Detected\recgonize_happy141.jpg
# E:\face_dectection\Detected\recgonize_happy142.jpg
# E:\face_dectection\Detected\recgonize_happy143.jpg
# E:\face_dectection\Detected\recgonize_happy144.jpg
# E:\face_dectection\Detected\recgonize_happy145.jpg
# E:\face_dectection\Detected\recgonize_happy146.jpg
# E:\face_dectection\Detected\recgonize_happy147.jpg
# E:\face_dectection\Detected\recgonize_happy148.jpg
# E:\face_dectection\Detected\recgonize_happy149.jpg
# E:\face_dectection\Detected\recgonize_happy15.jpg
# E:\face_dectection\Detected\recgonize_happy150.jpg
# E:\face_dectection\Detected\recgonize_happy151.jpg
# E:\face_dectection\Detected\recgonize_happy152.jpg
# E:\face_dectection\Detected\recgonize_happy153.jpg
# E:\face_dectection\Detected\recgonize_happy154.jpg
# E:\face_dectection\Detected\recgonize_happy155.jpg
# E:\face_dectection\Detected\recgonize_happy156.jpg
# E:\face_dectection\Detected\recgonize_happy157.jpg
# E:\face_dectection\Detected\recgonize_happy158.jpg
# E:/face_dectection/emotion/happy\recgonize_happy170.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy159.jpg
# E:\face_dectection\Detected\recgonize_happy16.jpg
# E:\face_dectection\Detected\recgonize_happy160.jpg
# E:\face_dectection\Detected\recgonize_happy161.jpg
# E:\face_dectection\Detected\recgonize_happy162.jpg
# E:\face_dectection\Detected\recgonize_happy163.jpg
# E:\face_dectection\Detected\recgonize_happy164.jpg
# E:/face_dectection/emotion/happy\recgonize_happy178.jpgis not done!
# E:/face_dectection/emotion/happy\recgonize_happy179.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy165.jpg
# E:\face_dectection\Detected\recgonize_happy166.jpg
# E:\face_dectection\Detected\recgonize_happy167.jpg
# E:\face_dectection\Detected\recgonize_happy168.jpg
# E:/face_dectection/emotion/happy\recgonize_happy184.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy169.jpg
# E:\face_dectection\Detected\recgonize_happy17.jpg
# E:\face_dectection\Detected\recgonize_happy170.jpg
# E:/face_dectection/emotion/happy\recgonize_happy188.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy171.jpg
# E:\face_dectection\Detected\recgonize_happy172.jpg
# E:\face_dectection\Detected\recgonize_happy173.jpg
# E:\face_dectection\Detected\recgonize_happy174.jpg
# E:\face_dectection\Detected\recgonize_happy175.jpg
# E:\face_dectection\Detected\recgonize_happy176.jpg
# E:\face_dectection\Detected\recgonize_happy177.jpg
# E:\face_dectection\Detected\recgonize_happy178.jpg
# E:\face_dectection\Detected\recgonize_happy179.jpg
# E:\face_dectection\Detected\recgonize_happy18.jpg
# E:\face_dectection\Detected\recgonize_happy180.jpg
# E:\face_dectection\Detected\recgonize_happy181.jpg
# E:\face_dectection\Detected\recgonize_happy182.jpg
# E:\face_dectection\Detected\recgonize_happy183.jpg
# E:\face_dectection\Detected\recgonize_happy184.jpg
# E:\face_dectection\Detected\recgonize_happy185.jpg
# E:\face_dectection\Detected\recgonize_happy186.jpg
# E:\face_dectection\Detected\recgonize_happy187.jpg
# E:\face_dectection\Detected\recgonize_happy188.jpg
# E:\face_dectection\Detected\recgonize_happy189.jpg
# E:/face_dectection/emotion/happy\recgonize_happy209.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy19.jpg
# E:\face_dectection\Detected\recgonize_happy190.jpg
# E:\face_dectection\Detected\recgonize_happy191.jpg
# E:\face_dectection\Detected\recgonize_happy192.jpg
# E:\face_dectection\Detected\recgonize_happy193.jpg
# E:\face_dectection\Detected\recgonize_happy194.jpg
# E:\face_dectection\Detected\recgonize_happy195.jpg
# E:\face_dectection\Detected\recgonize_happy196.jpg
# E:\face_dectection\Detected\recgonize_happy197.jpg
# E:/face_dectection/emotion/happy\recgonize_happy219.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy198.jpg
# E:\face_dectection\Detected\recgonize_happy199.jpg
# E:\face_dectection\Detected\recgonize_happy2.jpg
# E:/face_dectection/emotion/happy\recgonize_happy224.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy20.jpg
# E:\face_dectection\Detected\recgonize_happy200.jpg
# E:/face_dectection/emotion/happy\recgonize_happy227.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy201.jpg
# E:\face_dectection\Detected\recgonize_happy202.jpg
# E:\face_dectection\Detected\recgonize_happy203.jpg
# E:\face_dectection\Detected\recgonize_happy204.jpg
# E:/face_dectection/emotion/happy\recgonize_happy231.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy205.jpg
# E:\face_dectection\Detected\recgonize_happy206.jpg
# E:\face_dectection\Detected\recgonize_happy207.jpg
# E:\face_dectection\Detected\recgonize_happy208.jpg
# E:\face_dectection\Detected\recgonize_happy209.jpg
# E:\face_dectection\Detected\recgonize_happy21.jpg
# E:\face_dectection\Detected\recgonize_happy210.jpg
# E:\face_dectection\Detected\recgonize_happy211.jpg
# E:/face_dectection/emotion/happy\recgonize_happy24.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy212.jpg
# E:\face_dectection\Detected\recgonize_happy213.jpg
# E:\face_dectection\Detected\recgonize_happy214.jpg
# E:\face_dectection\Detected\recgonize_happy215.jpg
# E:\face_dectection\Detected\recgonize_happy216.jpg
# E:\face_dectection\Detected\recgonize_happy217.jpg
# E:/face_dectection/emotion/happy\recgonize_happy248.jpgis not done!
# E:/face_dectection/emotion/happy\recgonize_happy249.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy218.jpg
# E:\face_dectection\Detected\recgonize_happy219.jpg
# E:\face_dectection\Detected\recgonize_happy22.jpg
# E:\face_dectection\Detected\recgonize_happy220.jpg
# E:\face_dectection\Detected\recgonize_happy221.jpg
# E:\face_dectection\Detected\recgonize_happy222.jpg
# E:\face_dectection\Detected\recgonize_happy223.jpg
# E:\face_dectection\Detected\recgonize_happy224.jpg
# E:/face_dectection/emotion/happy\recgonize_happy258.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy225.jpg
# E:\face_dectection\Detected\recgonize_happy226.jpg
# E:\face_dectection\Detected\recgonize_happy227.jpg
# E:\face_dectection\Detected\recgonize_happy228.jpg
# E:\face_dectection\Detected\recgonize_happy229.jpg
# E:/face_dectection/emotion/happy\recgonize_happy263.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy23.jpg
# E:\face_dectection\Detected\recgonize_happy230.jpg
# E:/face_dectection/emotion/happy\recgonize_happy266.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy231.jpg
# E:\face_dectection\Detected\recgonize_happy232.jpg
# E:\face_dectection\Detected\recgonize_happy233.jpg
# E:\face_dectection\Detected\recgonize_happy234.jpg
# E:/face_dectection/emotion/happy\recgonize_happy271.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy235.jpg
# E:\face_dectection\Detected\recgonize_happy236.jpg
# E:\face_dectection\Detected\recgonize_happy237.jpg
# E:\face_dectection\Detected\recgonize_happy238.jpg
# E:/face_dectection/emotion/happy\recgonize_happy276.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy239.jpg
# E:\face_dectection\Detected\recgonize_happy24.jpg
# E:\face_dectection\Detected\recgonize_happy240.jpg
# E:\face_dectection\Detected\recgonize_happy241.jpg
# E:\face_dectection\Detected\recgonize_happy242.jpg
# E:\face_dectection\Detected\recgonize_happy243.jpg
# E:\face_dectection\Detected\recgonize_happy244.jpg
# E:\face_dectection\Detected\recgonize_happy245.jpg
# E:\face_dectection\Detected\recgonize_happy246.jpg
# E:\face_dectection\Detected\recgonize_happy247.jpg
# E:\face_dectection\Detected\recgonize_happy248.jpg
# E:/face_dectection/emotion/happy\recgonize_happy288.jpgis not done!
# E:/face_dectection/emotion/happy\recgonize_happy289.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy249.jpg
# E:\face_dectection\Detected\recgonize_happy25.jpg
# E:\face_dectection\Detected\recgonize_happy250.jpg
# E:\face_dectection\Detected\recgonize_happy251.jpg
# E:\face_dectection\Detected\recgonize_happy252.jpg
# E:\face_dectection\Detected\recgonize_happy253.jpg
# E:\face_dectection\Detected\recgonize_happy254.jpg
# E:\face_dectection\Detected\recgonize_happy255.jpg
# E:\face_dectection\Detected\recgonize_happy256.jpg
# E:\face_dectection\Detected\recgonize_happy257.jpg
# E:\face_dectection\Detected\recgonize_happy258.jpg
# E:\face_dectection\Detected\recgonize_happy259.jpg
# E:/face_dectection/emotion/happy\recgonize_happy300.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy26.jpg
# E:\face_dectection\Detected\recgonize_happy260.jpg
# E:/face_dectection/emotion/happy\recgonize_happy303.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy261.jpg
# E:\face_dectection\Detected\recgonize_happy262.jpg
# E:\face_dectection\Detected\recgonize_happy263.jpg
# E:\face_dectection\Detected\recgonize_happy264.jpg
# E:/face_dectection/emotion/happy\recgonize_happy308.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy265.jpg
# E:\face_dectection\Detected\recgonize_happy266.jpg
# E:\face_dectection\Detected\recgonize_happy267.jpg
# E:\face_dectection\Detected\recgonize_happy268.jpg
# E:\face_dectection\Detected\recgonize_happy269.jpg
# E:/face_dectection/emotion/happy\recgonize_happy313.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy27.jpg
# E:\face_dectection\Detected\recgonize_happy270.jpg
# E:\face_dectection\Detected\recgonize_happy271.jpg
# E:\face_dectection\Detected\recgonize_happy272.jpg
# E:\face_dectection\Detected\recgonize_happy273.jpg
# E:\face_dectection\Detected\recgonize_happy274.jpg
# E:\face_dectection\Detected\recgonize_happy275.jpg
# E:\face_dectection\Detected\recgonize_happy276.jpg
# E:\face_dectection\Detected\recgonize_happy277.jpg
# E:\face_dectection\Detected\recgonize_happy278.jpg
# E:\face_dectection\Detected\recgonize_happy279.jpg
# E:/face_dectection/emotion/happy\recgonize_happy325.jpgis not done!
# E:/face_dectection/emotion/happy\recgonize_happy326.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy28.jpg
# E:\face_dectection\Detected\recgonize_happy280.jpg
# E:\face_dectection\Detected\recgonize_happy281.jpg
# E:\face_dectection\Detected\recgonize_happy282.jpg
# E:\face_dectection\Detected\recgonize_happy283.jpg
# E:\face_dectection\Detected\recgonize_happy284.jpg
# E:/face_dectection/emotion/happy\recgonize_happy332.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy285.jpg
# E:\face_dectection\Detected\recgonize_happy286.jpg
# E:\face_dectection\Detected\recgonize_happy287.jpg
# E:\face_dectection\Detected\recgonize_happy288.jpg
# E:\face_dectection\Detected\recgonize_happy289.jpg
# E:/face_dectection/emotion/happy\recgonize_happy338.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy29.jpg
# E:\face_dectection\Detected\recgonize_happy290.jpg
# E:\face_dectection\Detected\recgonize_happy291.jpg
# E:\face_dectection\Detected\recgonize_happy292.jpg
# E:\face_dectection\Detected\recgonize_happy293.jpg
# E:\face_dectection\Detected\recgonize_happy294.jpg
# E:\face_dectection\Detected\recgonize_happy295.jpg
# E:\face_dectection\Detected\recgonize_happy296.jpg
# E:\face_dectection\Detected\recgonize_happy297.jpg
# E:\face_dectection\Detected\recgonize_happy298.jpg
# E:\face_dectection\Detected\recgonize_happy299.jpg
# E:\face_dectection\Detected\recgonize_happy3.jpg
# E:\face_dectection\Detected\recgonize_happy30.jpg
# E:\face_dectection\Detected\recgonize_happy300.jpg
# E:\face_dectection\Detected\recgonize_happy301.jpg
# E:\face_dectection\Detected\recgonize_happy302.jpg
# E:\face_dectection\Detected\recgonize_happy303.jpg
# E:/face_dectection/emotion/happy\recgonize_happy355.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy304.jpg
# E:/face_dectection/emotion/happy\recgonize_happy357.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy305.jpg
# E:\face_dectection\Detected\recgonize_happy306.jpg
# E:\face_dectection\Detected\recgonize_happy307.jpg
# E:\face_dectection\Detected\recgonize_happy308.jpg
# E:\face_dectection\Detected\recgonize_happy309.jpg
# E:\face_dectection\Detected\recgonize_happy31.jpg
# E:\face_dectection\Detected\recgonize_happy310.jpg
# E:\face_dectection\Detected\recgonize_happy311.jpg
# E:\face_dectection\Detected\recgonize_happy312.jpg
# E:\face_dectection\Detected\recgonize_happy313.jpg
# E:\face_dectection\Detected\recgonize_happy314.jpg
# E:\face_dectection\Detected\recgonize_happy315.jpg
# E:/face_dectection/emotion/happy\recgonize_happy369.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy316.jpg
# E:/face_dectection/emotion/happy\recgonize_happy370.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy317.jpg
# E:\face_dectection\Detected\recgonize_happy318.jpg
# E:\face_dectection\Detected\recgonize_happy319.jpg
# E:\face_dectection\Detected\recgonize_happy32.jpg
# E:/face_dectection/emotion/happy\recgonize_happy375.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy320.jpg
# E:/face_dectection/emotion/happy\recgonize_happy377.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy321.jpg
# E:\face_dectection\Detected\recgonize_happy322.jpg
# E:\face_dectection\Detected\recgonize_happy323.jpg
# E:\face_dectection\Detected\recgonize_happy324.jpg
# E:/face_dectection/emotion/happy\recgonize_happy382.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy325.jpg
# E:\face_dectection\Detected\recgonize_happy326.jpg
# E:\face_dectection\Detected\recgonize_happy327.jpg
# E:\face_dectection\Detected\recgonize_happy328.jpg
# E:\face_dectection\Detected\recgonize_happy329.jpg
# E:\face_dectection\Detected\recgonize_happy33.jpg
# E:/face_dectection/emotion/happy\recgonize_happy39.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy330.jpg
# E:\face_dectection\Detected\recgonize_happy331.jpg
# E:\face_dectection\Detected\recgonize_happy332.jpg
# E:\face_dectection\Detected\recgonize_happy333.jpg
# E:\face_dectection\Detected\recgonize_happy334.jpg
# E:\face_dectection\Detected\recgonize_happy335.jpg
# E:\face_dectection\Detected\recgonize_happy336.jpg
# E:\face_dectection\Detected\recgonize_happy337.jpg
# E:\face_dectection\Detected\recgonize_happy338.jpg
# E:\face_dectection\Detected\recgonize_happy339.jpg
# E:\face_dectection\Detected\recgonize_happy34.jpg
# E:\face_dectection\Detected\recgonize_happy340.jpg
# E:\face_dectection\Detected\recgonize_happy341.jpg
# E:\face_dectection\Detected\recgonize_happy342.jpg
# E:\face_dectection\Detected\recgonize_happy343.jpg
# E:\face_dectection\Detected\recgonize_happy344.jpg
# E:\face_dectection\Detected\recgonize_happy345.jpg
# E:\face_dectection\Detected\recgonize_happy346.jpg
# E:\face_dectection\Detected\recgonize_happy347.jpg
# E:\face_dectection\Detected\recgonize_happy348.jpg
# E:\face_dectection\Detected\recgonize_happy349.jpg
# E:\face_dectection\Detected\recgonize_happy35.jpg
# E:/face_dectection/emotion/happy\recgonize_happy412.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy350.jpg
# E:\face_dectection\Detected\recgonize_happy351.jpg
# E:\face_dectection\Detected\recgonize_happy352.jpg
# E:\face_dectection\Detected\recgonize_happy353.jpg
# E:\face_dectection\Detected\recgonize_happy354.jpg
# E:\face_dectection\Detected\recgonize_happy355.jpg
# E:\face_dectection\Detected\recgonize_happy356.jpg
# E:\face_dectection\Detected\recgonize_happy357.jpg
# E:/face_dectection/emotion/happy\recgonize_happy47.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy358.jpg
# E:\face_dectection\Detected\recgonize_happy359.jpg
# E:\face_dectection\Detected\recgonize_happy36.jpg
# E:\face_dectection\Detected\recgonize_happy360.jpg
# E:\face_dectection\Detected\recgonize_happy361.jpg
# E:\face_dectection\Detected\recgonize_happy362.jpg
# E:\face_dectection\Detected\recgonize_happy363.jpg
# E:\face_dectection\Detected\recgonize_happy364.jpg
# E:\face_dectection\Detected\recgonize_happy365.jpg
# E:\face_dectection\Detected\recgonize_happy366.jpg
# E:\face_dectection\Detected\recgonize_happy367.jpg
# E:\face_dectection\Detected\recgonize_happy368.jpg
# E:\face_dectection\Detected\recgonize_happy369.jpg
# E:\face_dectection\Detected\recgonize_happy37.jpg
# E:\face_dectection\Detected\recgonize_happy370.jpg
# E:/face_dectection/emotion/happy\recgonize_happy62.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy371.jpg
# E:\face_dectection\Detected\recgonize_happy372.jpg
# E:\face_dectection\Detected\recgonize_happy373.jpg
# E:\face_dectection\Detected\recgonize_happy374.jpg
# E:\face_dectection\Detected\recgonize_happy375.jpg
# E:\face_dectection\Detected\recgonize_happy376.jpg
# E:\face_dectection\Detected\recgonize_happy377.jpg
# E:\face_dectection\Detected\recgonize_happy378.jpg
# E:\face_dectection\Detected\recgonize_happy379.jpg
# E:\face_dectection\Detected\recgonize_happy38.jpg
# E:\face_dectection\Detected\recgonize_happy380.jpg
# E:\face_dectection\Detected\recgonize_happy381.jpg
# E:\face_dectection\Detected\recgonize_happy382.jpg
# E:\face_dectection\Detected\recgonize_happy383.jpg
# E:/face_dectection/emotion/happy\recgonize_happy77.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy384.jpg
# E:\face_dectection\Detected\recgonize_happy385.jpg
# E:\face_dectection\Detected\recgonize_happy386.jpg
# E:\face_dectection\Detected\recgonize_happy387.jpg
# E:\face_dectection\Detected\recgonize_happy388.jpg
# E:\face_dectection\Detected\recgonize_happy389.jpg
# E:\face_dectection\Detected\recgonize_happy39.jpg
# E:\face_dectection\Detected\recgonize_happy390.jpg
# E:/face_dectection/emotion/happy\recgonize_happy85.jpgis not done!
# E:\face_dectection\Detected\recgonize_happy391.jpg
# E:\face_dectection\Detected\recgonize_happy392.jpg
# E:\face_dectection\Detected\recgonize_happy393.jpg
# E:\face_dectection\Detected\recgonize_happy394.jpg
# E:\face_dectection\Detected\recgonize_happy395.jpg
# E:\face_dectection\Detected\recgonize_happy396.jpg
# E:\face_dectection\Detected\recgonize_happy397.jpg
# E:\face_dectection\Detected\recgonize_happy398.jpg
# E:\face_dectection\Detected\recgonize_happy399.jpg
# E:\face_dectection\Detected\recgonize_happy4.jpg
# E:\face_dectection\Detected\recgonize_happy40.jpg
# E:\face_dectection\Detected\recgonize_happy400.jpg
# E:\face_dectection\Detected\recgonize_happy401.jpg
# E:\face_dectection\Detected\recgonize_happy402.jpg
# E:/face_dectection/emotion/happy\recgonize_happy99.jpgis not done!
# all dected image is done! plese check in your save path

# %%
#浅浅的展示一下效果
plt.imshow(temp_image[3],cmap = "gray")
#len(X)

# %% [markdown]
# ### 下面尝试进行人脸识别

# %%
shape_predictor_path = 'D:/face_dectection/shape_predictor_68_face_landmarks.dat' # 人脸检测器
recognition_model_path = 'D:/face_dectection/dlib_face_recognition_resnet_model_v1.dat'

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor(shape_predictor_path)                              # 人脸68点提取器
recognition_model = dlib.face_recognition_model_v1(recognition_model_path)          # 基于resnet的128维特征向量提取器

# %%
import cv2 as cv
import os
import numpy as np
import csv
import config
from tqdm import tqdm
import shutil

def write2csv(data, mode):                      # 更新库内所有数据
    with open(config.csv_base_path, mode, newline='') as wf:
        csv_writer = csv.writer(wf)
        csv_writer.writerow(data)

def get_features_from_csv():
    features_in_csv = []
    with open(config.csv_base_path, 'r') as rf:
        csv_reader = csv.reader(rf)
        for row in csv_reader:
            for i in range(0, 128):
                row[i] = float(row[i])

            features_in_csv.append(row)
        return features_in_csv

def save_select_in_csv(data):                   # 库内数据选择更新
    features_in_csv = get_features_from_csv()

    with open(config.csv_base_path, 'w', newline='') as wf:
        csv_writer = csv.writer(wf)
        for index, i in enumerate(config.face_needTo_update):
            features_in_csv[i] = data[index]

        csv_writer.writerow(features_in_csv[0])

    with open(config.csv_base_path, 'a+', newline='') as af:
        csv_writer = csv.writer(af)
        for j in range(1, len(features_in_csv)):
            csv_writer.writerow(features_in_csv[j])

    print("csv文件更新完成!!")

def get_128_features(person):                    # person代表第几个人脸数据文件夹
    num = 0
    features = []
    imgs_folder = config.imgs_folder_path[person]
    points_faceImage_path = config.points_faceData_path + imgs_folder

    imgs_path = config.faceData_path + imgs_folder + '/'
    list_imgs = os.listdir(imgs_path)
    imgs_num = len(list_imgs)

    if os.path.exists(config.points_faceData_path + imgs_folder):
        shutil.rmtree(points_faceImage_path)
    os.makedirs(points_faceImage_path)
    print("人脸点图文件夹建立成功!!")

    with tqdm(total=imgs_num) as pbar:
        pbar.set_description(str(imgs_folder))
        for j in range(imgs_num):
            image = cv.imread(os.path.join(imgs_path, list_imgs[j]))

            faces = config.detector(image, 1)           # 经查阅资料，这里的1代表采样次数
            if len(faces) != 0:
                for z, face in enumerate(faces):
                    shape = config.predictor(image, face)       # 获取68点的坐标

                    w, h = (face.right() - face.left()), (face.bottom() - face.top())
                    left, right, top, bottom = face.left() - w // 4, face.right() + w // 4, face.top() - h // 2, face.bottom() + h // 4
                    im = image

                    cv.rectangle(im, (left, top), (right, bottom), (0, 0, 255))
                    cv.imwrite(points_faceImage_path + '/{}.png'.format(j), im)

                    if config.get_points_faceData_flag == True:
                        for p in range(0, 68):
                            cv.circle(image, (shape.part(p).x, shape.part(p).y), 2, (0,0,255))
                        cv.imwrite(points_faceImage_path + '/{}.png'.format(j), image)

                    the_features = list(config.recognition_model.compute_face_descriptor(image, shape)) # 获取128维特征向量
                    features.append(the_features)
                    #print("第{}张图片，第{}张脸,特征向量为:{}".format(j+1, z+1, the_features))
                    num += 1
            pbar.update(1)

    np_f = np.array(features)
    #res = np.mean(np_f, axis=0)
    res = np.median(np_f, axis=0)

    return res

def main():
    #config is system config feature
    if config.import_all_features_flag == True:
        res = get_128_features(person=0)
        write2csv(res, 'w')
        for i in range(1, config.num_of_person_in_lib):
            res = get_128_features(person=i)
            write2csv(res, 'a+')
            #print("人脸特征向量为：{}".format(res))
    else:
        select_res = []
        for i in config.face_needTo_update:
            res = get_128_features(person=i)
            select_res.append(res)
        save_select_in_csv(select_res)

# %%
import numpy as np
import csv
import config
import cv2 as cv
from collect_face_data import face_detect

class face_recognition(face_detect):
    def __init__(self, cam):
        super(face_recognition, self).__init__()
        self.camera = cam
        self.available_max_face_num = 50        # 最大的人脸检测数量(不一定能达到)
        self.collect_face_data = False          # 人脸识别过程不采集数据，固定为False

        self.all_features = []                  # 存储库中所有特征向量
        self.check_features_from_cam = []       # 存储五次检测过程，每次得到的特征向量

        self.person_name = []                   # 存储人名
        self.all_name = []                      # 存储预测到的所有人名

        self.all_face_location = None           # 存储一帧中所有人脸的坐标
        self.middle_point = None                # 存储一张人脸的中心点坐标
        self.last_frame_middle_point = []       # 存储上一帧所有人脸的中心点坐标

        self.all_e_distance = []                # 存储当前人脸与库中所有人脸特征的欧氏距离
        self.last_now_middlePoint_eDistance = [99999 for x in range(self.available_max_face_num)]   # 存储这帧与上一帧每张人脸中心点的欧氏距离

        for i in range(self.available_max_face_num):
            self.all_e_distance.append([])
            self.person_name.append([])
            self.check_features_from_cam.append([])
            self.last_frame_middle_point.append([])

    def get_feature_in_csv(self):                                       # 获得库内所有特征向量
        datas = csv.reader(open(config.csv_base_path, 'r'))
        for row in datas:
            for i in range(128):
                row[i] = float(row[i])

            self.all_features.append(row)

    def get_faceName(self):                                             # 获得库内所有人名
        with open(config.faceName_path, 'r', encoding='utf-8') as f:
            datas = f.readlines()
            for line in datas:
                self.all_name.append(line[:-1])
            print("库中存在的人名有：{}".format(self.all_name))

    def calculate_EuclideanDistance(self, feature1, feature2):          # 计算欧氏距离
        np_feature1 = np.array(feature1)
        np_feature2 = np.array(feature2)

        EuclideanDistance = np.sqrt(np.sum(np.square(np_feature1 - np_feature2)))

        return EuclideanDistance

    def meadian_filter(self, the_list, num_of_data):
        np_list = np.array(the_list)
        feature_max = np.max(np_list, axis=0)
        feature_min = np.min(np_list, axis=0)
        res = (np.sum(np_list, axis=0) - feature_max - feature_min) / (num_of_data-2)

        res.tolist()
        return res

    def middle_filter(self, the_list):
        np_list = np.array(the_list)
        return np.median(np_list, axis=0)

    def init_process(self):
        self.get_feature_in_csv()
        self.get_faceName()

    def track_link(self):           # 这个函数是为了让后续帧的序号与初始帧的序号对应
        for index in range(self.face_num):
            self.last_now_middlePoint_eDistance[index] = self.calculate_EuclideanDistance(self.middle_point,
                                                                              self.last_frame_middle_point[index])
        this_face_index = self.last_now_middlePoint_eDistance.index(min(self.last_now_middlePoint_eDistance))
        self.last_frame_middle_point[this_face_index] = self.middle_point

        return this_face_index

    def recognition_from_cam(self):
        self.init_process()
        while self.camera.isOpened() and not self.quit_flag:
            val, self.image = self.camera.read()
            if val == False: continue

            #self.image = cv.imread('./data/test/test_xi.jpg')
            #self.image = cv.imread('./data/test/multi.png')

            key = cv.waitKey(1)

            res = self.face_detecting()         # 0.038s

            if res is not None:
                face, self.all_face_location = res

                for i in range(self.face_num):
                    [left, right, top, bottom] = self.all_face_location[i]
                    self.middle_point = [(left + right) /2, (top + bottom) / 2]

                    self.face_img = self.image[top:bottom, left:right]

                    cv.rectangle(self.image, (left, top), (right, bottom), (0, 0, 255))

                    shape = config.predictor(self.image, face[i])       # 0.002s

                    if self.face_num_change_flag == True or self.check_times <= 5:
                        if self.face_num_change_flag == True:       # 人脸数量有变化，重新进行五次检测
                            self.check_times = 0
                            self.last_now_middlePoint_eDistance = [99999 for _ in range(self.available_max_face_num)]
                            for z in range(self.available_max_face_num):    self.check_features_from_cam[z] = []

                        if self.check_times < 5:
                            the_features_from_cam = list(config.recognition_model.compute_face_descriptor(self.image, shape))   # 耗时主要在这步 0.32s
                            if self.check_times == 0:           # 初始帧
                                self.check_features_from_cam[i].append(the_features_from_cam)
                                self.last_frame_middle_point[i] = self.middle_point
                            else:
                                this_face_index = self.track_link()         # 后续帧需要与初始帧的人脸序号对应
                                self.check_features_from_cam[this_face_index].append(the_features_from_cam)

                        elif self.check_times == 5:
                            features_after_filter = self.middle_filter(self.check_features_from_cam[i])
                            self.check_features_from_cam[i] = []
                            for person in range(config.num_of_person_in_lib):
                                e_distance = self.calculate_EuclideanDistance(self.all_features[person],
                                                                              features_after_filter)  # 几乎不耗时

                                self.all_e_distance[i].append(e_distance)

                            if min(self.all_e_distance[i]) < config.recognition_threshold:
                                self.person_name[i] = self.all_name[self.all_e_distance[i].index(min(self.all_e_distance[i]))]
                                cv.putText(self.image, self.person_name[i],
                                           (int((left + right) / 2) - 50, bottom + 20),
                                           cv.FONT_HERSHEY_COMPLEX, 1, (255, 255, 255))
                            else:
                                self.person_name[i] = "Unknown"

                            print("预测结果为:{}, 与库中各人脸的欧氏距离为:{}".format(self.person_name[i], self.all_e_distance[i]))

                    else:
                        this_face_index = self.track_link()
                        #print(this_face_index, self.person_name)
                        cv.putText(self.image, self.person_name[this_face_index], (int((left + right) / 2) - 50, bottom + 20),
                                   cv.FONT_HERSHEY_COMPLEX, 1, (255, 255, 255))
                self.check_times += 1

                for j in range(self.available_max_face_num):
                    self.all_e_distance[j] = []

                self.key_scan(key)

            self.get_fps()
            cv.namedWindow('camera', 0)
            cv.imshow('camera', self.image)

        self.camera.release()
        cv.destroyAllWindows()

def main():
    cam = cv.VideoCapture(0)
    process = face_recognition(cam)
    process.recognition_from_cam()

if __name__ == '__main__':
    main()
